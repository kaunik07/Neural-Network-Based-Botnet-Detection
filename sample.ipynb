# %%
import pandas as pd
import numpy as np
df = pd.read_csv('dataset1.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1,3,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.columns = ['srcip','sport','dstsip','dsport','proto','state','dur','sbytes','dbytes','sttl','dttl','sloss','dloss','service','sload','dload','spkts','dpkts','swin','dwin','stcpb','dtcpb','smeansz','dmeansz','trans_dept','res_bdy_len','sjit','djit','stime','ltime','sintpkt','dintpkt','tcprtt','synack','ackdat','is_sn_ips_ports','ct_state_ttl','ct_flw_http_mthd','is_ftp_login','ct_ftp_cmd','ct_srv_src','ct_srv_dst','ct_dst_ltm','ct_src_ltm','ct_src_dport_ltm','ct_dst_sport_ltm','ct_dst_src_ltm','attack_cat','label']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700000 entries, 0 to 699999
# Data columns (total 49 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   srcip             700000 non-null  object
#  1   sport             700000 non-null  object
#  2   dstsip            700000 non-null  object
#  3   dsport            700000 non-null  object
#  4   proto             700000 non-null  object
#  5   state             700000 non-null  object
#  6   dur               700000 non-null  float64
#  7   sbytes            700000 non-null  int64
#  8   dbytes            700000 non-null  int64
#  9   sttl              700000 non-null  int64
#  10  dttl              700000 non-null  int64
#  11  sloss             700000 non-null  int64
#  12  dloss             700000 non-null  int64
#  13  service           700000 non-null  object
#  14  sload             700000 non-null  float64
#  15  dload             700000 non-null  float64
# ...

# %%
df['label'].value_counts()
# Out:
# 0    677786
# 1     22215
# Name: label, dtype: int64

# %%
df3 = pd.read_csv('dataset3.csv')
df3.columns = ['srcip','sport','dstsip','dsport','proto','state','dur','sbytes','dbytes','sttl','dttl','sloss','dloss','service','sload','dload','spkts','dpkts','swin','dwin','stcpb','dtcpb','smeansz','dmeansz','trans_dept','res_bdy_len','sjit','djit','stime','ltime','sintpkt','dintpkt','tcprtt','synack','ackdat','is_sn_ips_ports','ct_state_ttl','ct_flw_http_mthd','is_ftp_login','ct_ftp_cmd','ct_srv_src','ct_srv_dst','ct_dst_ltm','ct_src_ltm','ct_src_dport_ltm','ct_dst_sport_ltm','ct_dst_src_ltm','attack_cat','label']

# %%
df3['label'].value_counts()
# Out:
# 0    542575
# 1    157425
# Name: label, dtype: int64

# %%
df2 = pd.read_csv('dataset2.csv')
df2.columns = ['srcip','sport','dstsip','dsport','proto','state','dur','sbytes','dbytes','sttl','dttl','sloss','dloss','service','sload','dload','spkts','dpkts','swin','dwin','stcpb','dtcpb','smeansz','dmeansz','trans_dept','res_bdy_len','sjit','djit','stime','ltime','sintpkt','dintpkt','tcprtt','synack','ackdat','is_sn_ips_ports','ct_state_ttl','ct_flw_http_mthd','is_ftp_login','ct_ftp_cmd','ct_srv_src','ct_srv_dst','ct_dst_ltm','ct_src_ltm','ct_src_dport_ltm','ct_dst_sport_ltm','ct_dst_src_ltm','attack_cat','label']
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,39,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700000 entries, 0 to 699999
# Data columns (total 49 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   srcip             700000 non-null  object
#  1   sport             700000 non-null  int64
#  2   dstsip            700000 non-null  object
#  3   dsport            700000 non-null  object
#  4   proto             700000 non-null  object
#  5   state             700000 non-null  object
#  6   dur               700000 non-null  float64
#  7   sbytes            700000 non-null  int64
#  8   dbytes            700000 non-null  int64
#  9   sttl              700000 non-null  int64
#  10  dttl              700000 non-null  int64
#  11  sloss             700000 non-null  int64
#  12  dloss             700000 non-null  int64
#  13  service           700000 non-null  object
#  14  sload             700000 non-null  float64
#  15  dload             700000 non-null  float64
# ...

# %%
df2['label'].value_counts()
# Out:
# 0    647251
# 1     52749
# Name: label, dtype: int64

# %%
df4 = pd.read_csv('dataset4.csv')
df4.columns = ['srcip','sport','dstsip','dsport','proto','state','dur','sbytes','dbytes','sttl','dttl','sloss','dloss','service','sload','dload','spkts','dpkts','swin','dwin','stcpb','dtcpb','smeansz','dmeansz','trans_dept','res_bdy_len','sjit','djit','stime','ltime','sintpkt','dintpkt','tcprtt','synack','ackdat','is_sn_ips_ports','ct_state_ttl','ct_flw_http_mthd','is_ftp_login','ct_ftp_cmd','ct_srv_src','ct_srv_dst','ct_dst_ltm','ct_src_ltm','ct_src_dport_ltm','ct_dst_sport_ltm','ct_dst_src_ltm','attack_cat','label']

# %%
df4['label'].value_counts()
# Out:
# 0    351149
# 1     88894
# Name: label, dtype: int64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440043 entries, 0 to 440042
# Data columns (total 49 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   srcip             440043 non-null  object
#  1   sport             440043 non-null  int64
#  2   dstsip            440043 non-null  object
#  3   dsport            440043 non-null  object
#  4   proto             440043 non-null  object
#  5   state             440043 non-null  object
#  6   dur               440043 non-null  float64
#  7   sbytes            440043 non-null  int64
#  8   dbytes            440043 non-null  int64
#  9   sttl              440043 non-null  int64
#  10  dttl              440043 non-null  int64
#  11  sloss             440043 non-null  int64
#  12  dloss             440043 non-null  int64
#  13  service           440043 non-null  object
#  14  sload             440043 non-null  float64
#  15  dload             440043 non-null  float64
# ...

# %%
botnet1 = df[df.label == 1]
botnet2 = df2[df2.label == 1]
botnet4 = df4[df4.label == 1]

# %%
botnet1
# Out:
#                srcip  sport          dstsip dsport proto state        dur  \
# 20      175.45.176.3  21223  149.171.126.18  32780   udp   INT   0.000021
# 21      175.45.176.2  23357  149.171.126.16     80   tcp   FIN   0.240139
# 22      175.45.176.0  13284  149.171.126.16     80   tcp   FIN   2.390390
# 39      175.45.176.2  13792  149.171.126.16   5555   tcp   FIN   0.175190
# 40      175.45.176.2  26939  149.171.126.10     80   tcp   FIN   0.190600
# ...              ...    ...             ...    ...   ...   ...        ...
# 186498  175.45.176.1  58463  149.171.126.15    179   tcp   FIN  31.461020
# 186499  175.45.176.1  58460  149.171.126.15    179   tcp   FIN  57.995934
# 186562  175.45.176.1  58967  149.171.126.15    179   tcp   FIN  32.361782
# 186658  175.45.176.1  58485  149.171.126.15    179   tcp   FIN   0.476639
# 186787  175.45.176.1  58935  149.171.126.15    179   tcp   FIN   0.343431
#
#         sbytes  dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  \
# ...

# %%
botnet2
# Out:
#                srcip  sport          dstsip dsport proto state       dur  \
# 387246  175.45.176.0   7302  149.171.126.18     80   tcp   FIN  0.536452
# 387266  175.45.176.0      0  149.171.126.12      0  ospf   INT  0.921987
# 387267  175.45.176.0      0  149.171.126.12      0  ospf   INT  0.921987
# 387268  175.45.176.0      0  149.171.126.12      0  ospf   INT  0.921987
# 387269  175.45.176.0      0  149.171.126.12      0  ospf   INT  0.921987
# ...              ...    ...             ...    ...   ...   ...       ...
# 699933  175.45.176.3   1043  149.171.126.18     53   udp   INT  0.000003
# 699934  175.45.176.1  13540  149.171.126.10     80   tcp   FIN  3.393675
# 699935  175.45.176.0  34233  149.171.126.15   1723   tcp   FIN  0.586488
# 699984  175.45.176.1  61247  149.171.126.17    110   tcp   FIN  2.014088
# 699985  175.45.176.1   6870  149.171.126.17     80   tcp   FIN  0.771105
#
#         sbytes  dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  \
# ...

# %%
botnet4
# Out:
#                srcip  sport          dstsip dsport proto state       dur  \
# 5       175.45.176.0  49582  149.171.126.12     80   tcp   FIN  0.189983
# 6       175.45.176.1      0  149.171.126.11      0  sctp   INT  0.000009
# 7       175.45.176.1      0  149.171.126.11      0  sctp   INT  0.000009
# 8       175.45.176.1      0  149.171.126.11      0  sctp   INT  0.000009
# 9       175.45.176.1      0  149.171.126.11      0  sctp   INT  0.000009
# ...              ...    ...             ...    ...   ...   ...       ...
# 440023  175.45.176.0  47439  149.171.126.10     53   udp   INT  0.000001
# 440024  175.45.176.0  17293  149.171.126.17    110   tcp   CON  0.942984
# 440025  175.45.176.0  33654  149.171.126.12     80   tcp   CON  2.579405
# 440026  175.45.176.0  33654  149.171.126.12     80   tcp   CON  2.579405
# 440042  175.45.176.0  17293  149.171.126.17    110   tcp   CON  0.942984
#
#         sbytes  dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  \
# ...

# %%
df3 = df3.append(botnet1)

# %%
df3 = df3.append(botnet2)

# %%
df3 = df3.append(botnet4)

# %%
df3['label'].value_counts()
# Out:
# 0    542575
# 1    321283
# Name: label, dtype: int64

# %%
df3.to_csv('dataset.csv')

# %%
db = pd.read_csv('dataset.csv')

# %%
db.columns =['sno','srcip','sport','dstsip','dsport','proto','state','dur','sbytes','dbytes','sttl','dttl','sloss','dloss','service','sload','dload','spkts','dpkts','swin','dwin','stcpb','dtcpb','smeansz','dmeansz','trans_dept','res_bdy_len','sjit','djit','stime','ltime','sintpkt','dintpkt','tcprtt','synack','ackdat','is_sn_ips_ports','ct_state_ttl','ct_flw_http_mthd','is_ftp_login','ct_ftp_cmd','ct_srv_src','ct_srv_dst','ct_dst_ltm','ct_src_ltm','ct_src_dport_ltm','ct_dst_sport_ltm','ct_dst_src_ltm','attack_cat','label']

# %%
db = pd.read_csv('dataset.csv',index_col = "sno")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-da2d8429fefb> in <module>
# ----> 1 db = pd.read_csv('dataset.csv',index_col = "sno")
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
# ...
