# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121076 entries, 0 to 1121075
# Data columns (total 33 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   SrcAddr     1121076 non-null  object
#  1   DstAddr     1121076 non-null  object
#  2   Proto       1121076 non-null  object
#  3   Sport       1119481 non-null  object
#  4   Dport       1119485 non-null  object
#  5   State       1121057 non-null  object
#  6   sTos        1112996 non-null  float64
#  7   dTos        1039504 non-null  float64
#  8   SrcWin      287545 non-null   float64
#  9   DstWin      268427 non-null   float64
#  10  sHops       1112996 non-null  float64
#  11  dHops       1039504 non-null  float64
#  12  StartTime   1121076 non-null  object
#  13  LastTime    1121076 non-null  object
#  14  sTtl        1112996 non-null  float64
#  15  dTtl        1039504 non-null  float64
#  16  TcpRtt      1121076 non-null  float64
# ...

# %%
df.sample(n=10)
# Out:
#                SrcAddr         DstAddr Proto  Sport  Dport State  sTos  dTos  \
# 724946   147.32.84.138     147.32.80.9   udp  58911     53   CON   0.0   0.0
# 738342    147.32.84.59   77.93.192.144   tcp   2186     80   RST   0.0   0.0
# 942543   147.32.84.229   77.35.238.205   udp  13363  51582   CON   0.0   0.0
# 95902     147.32.84.59  87.106.145.225   tcp  57779     80   FIN   0.0   0.0
# 113273     68.235.66.3   147.32.84.229   udp  13135  13363   CON   0.0   0.0
# 657880   147.32.84.229   24.222.126.83   udp  13363  38049   CON   0.0   0.0
# 504191   147.32.84.138     147.32.80.9   udp  33680     53   CON   0.0   0.0
# 665536    147.32.84.59    95.65.64.125   udp  60276  39987   CON   0.0   0.0
# 1091528   147.32.84.24     147.32.80.9   udp  51541     53   CON   0.0   0.0
# 301624   78.80.181.135   147.32.84.229   udp   5854  13363   CON   0.0   0.0
#
#           SrcWin   DstWin  ...  SAppBytes  DAppBytes          Dur TotPkts  \
# ...

# %%
df.head(5)
# Out:
#          SrcAddr        DstAddr Proto  Sport Dport State  sTos  dTos  \
# 0  94.162.236.67  147.32.84.118   tcp   1958  6881   RST   0.0   0.0
# 1  88.212.36.177  147.32.84.118   tcp  44942  6881   RST   0.0   0.0
# 2    94.44.50.44  147.32.84.118   tcp  55008  6881   RST   0.0   0.0
# 3   94.165.0.151  147.32.84.118   tcp   3079  6881   RST   0.0   0.0
# 4   94.44.59.251  147.32.84.118   tcp   4390  6881   RST   0.0   0.0
#
#       SrcWin  DstWin  ...  SAppBytes  DAppBytes       Dur TotPkts  TotBytes  \
# 0   524280.0     0.0  ...          0          0  1.277892       4       252
# 1  2097152.0     0.0  ...          0          0  1.041958       4       252
# 2  2097152.0     0.0  ...          0          0  1.259001       4       252
# 3   262140.0     0.0  ...          0          0  1.129427       4       252
# 4   262140.0     0.0  ...          0          0  1.279737       4       252
#
#    TotAppByte      Rate   SrcRate   DstRate                        Label
# ...

# %%
df.iloc[4567:4590,[0,19,23]]
# Out:
#              SrcAddr  SrcPkts  SAppBytes
# 4567     24.30.35.54        2         66
# 4568    147.32.84.59        9       1101
# 4569   188.235.74.14       16        730
# 4570    147.32.85.18       13       3480
# 4571   147.32.86.194       82        396
# 4572  62.163.152.134       81       2673
# 4573   147.32.86.165        5       1166
# 4574  90.179.160.212       40        476
# 4575  90.179.160.212       11        212
# 4576    83.228.123.2        1         35
# 4577   147.32.86.106       76        190
# 4578  81.136.175.147        1         32
# 4579    83.228.123.2       10        165
# 4580    147.32.84.59        1         51
# 4581    147.32.84.59        1         38
# 4582    147.32.84.59        5       1112
# 4583   195.210.173.2        9       1200
# 4584  203.177.73.171        1         32
# 4585   147.32.84.186       12        576
# 4586  143.167.63.243      105      11115
# 4587    109.40.70.92       12        264
# 4588    27.44.23.200        2         72
# ...

# %%
len(df.SrcAddr.unique())
# Out:
# 131177

# %%
len(df.axes[0])
# Out:
# 1121076
